# %% [markdown]
# # 01 Python intermediate
# ## Programowanie Obiektowe (zaawansowane)
#
# _Kamil Bartocha_ - wersja 2.0

# %% [markdown]
# ## Rozkład jazdy
#
# 1. 🔹 **Podstawy OOP** - klasy, obiekty, atrybuty, metody
# 2. 🔹 **Dziedziczenie i `super()`** - MRO, wielopoziomowe
# 3. 🔹 **Hermetyzacja** - atrybuty prywatne, name mangling
# 4. 🔹 **Metody specjalne (dunder)** - `__str__`, `__add__`, `__eq__`
# 5. 🔹 **Metody klasowe** - `self` vs `cls`, `@classmethod`
#
# 🐍 Każda sekcja zawiera ćwiczenia.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. 🔹 Podstawy OOP
#
# Programowanie obiektowe (Object-Oriented Programming, OOP) to
# paradygmat, w którym organizujemy kod wokół **obiektów** - instancji
# klas. **Klasa (class)** to szablon definiujący atrybuty i metody.
# **Obiekt (object)** to konkretny egzemplarz klasy.
#
# Kluczowe pojęcia:
#
# - **klasa (class)** - szablon opisujący strukturę i zachowanie obiektów
# - **obiekt (object)** - instancja klasy, konkretny egzemplarz
# - **atrybut (attribute)** - zmienna przechowywana w obiekcie
# - **metoda (method)** - funkcja zdefiniowana wewnątrz klasy
# - **konstruktor (constructor)** - metoda `__init__`, wywoływana
#   automatycznie przy tworzeniu nowego obiektu
#
# > 💡 Każda metoda instancji przyjmuje `self` jako pierwszy parametr -
# > jest to odwołanie do konkretnego obiektu, na którym wywołujemy metodę.

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def description(self):
        return f"{self.make} {self.model}, year: {self.year}"


car1 = Car("BMW", "330i", 2020)
print(car1.description())
print(car1.make)

# %%
class Dog:
    def __init__(self, name, breed, age):
        self.name = name
        self.breed = breed
        self.age = age

    def bark(self):
        return f"{self.name} says Woof!"


dog1 = Dog("Buddy", "Golden Retriever", 3)
print(dog1.bark())

# %%
class Student:
    def __init__(self, name, student_id, grades):
        self.name = name
        self.student_id = student_id
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)


student1 = Student("Alice", "S12345", [90, 85, 88, 92])
print(student1.average_grade())

# %% [markdown]
# ---

# %% [markdown]
# ### 🐍 Ćwiczenia - Podstawy OOP
#
# **Ćw. 1.** Napisz klasę `Rectangle` z atrybutami `width` i `height`.
# Dodaj metody `area()` (pole) i `perimeter()` (obwód).
#
# **Ćw. 2.** Napisz klasę `Book` z atrybutami `title`, `author`, `year`.
# Dodaj metodę `get_info()` zwracającą czytelny opis książki w formacie:
# `'1984' by George Orwell, published in 1949`.
#
# **Ćw. 3. *(Trudniejsze)*** Napisz klasę `ShoppingCart`:
# - atrybut `items` jako pusta lista słowników `{name, price}`
# - metoda `add_item(name, price)` - dodaje przedmiot
# - metoda `remove_item(name)` - usuwa pierwszy pasujący
# - metoda `total()` - zwraca sumę cen
#
# **Ćw. 4.** Napisz klasę `Circle` z atrybutem `radius`.
# Dodaj metody `area()` (pi * r²) i `circumference()` (2 * pi * r).
#
# **Ćw. 5.** Napisz klasę `BankAccount` z atrybutami `owner` i `balance`
# (domyślnie 0). Dodaj metody `deposit(amount)`, `withdraw(amount)`
# (nie pozwalaj na wypłatę powyżej salda) i `get_balance()`.
#
# **Ćw. 6. *(Trudniejsze)*** Napisz klasę `Student` z atrybutem `name`
# i pustą listą `grades`. Dodaj metody `add_grade(grade)`, `average()`,
# `highest()`, `lowest()`.

# %%
# Ćw. 1: Klasa Rectangle
class Rectangle:
    def __init__(self, width, height):
        ...

    def area(self):
        ...

    def perimeter(self):
        ...


rect = Rectangle(5, 3)
print(rect.area())       # 15
print(rect.perimeter())  # 16

# %%
# Ćw. 2: Klasa Book
class Book:
    def __init__(self, title, author, year):
        ...

    def get_info(self):
        ...


book = Book("1984", "George Orwell", 1949)
print(book.get_info())
# '1984' by George Orwell, published in 1949

# %%
# Ćw. 3: Klasa ShoppingCart
class ShoppingCart:
    def __init__(self):
        ...

    def add_item(self, name, price):
        ...

    def remove_item(self, name):
        ...

    def total(self):
        ...


cart = ShoppingCart()
cart.add_item("Laptop", 1999)
cart.add_item("Mouse", 25)
print(cart.total())       # 2024
cart.remove_item("Mouse")
print(cart.total())       # 1999

# %%
# Ćw. 4: Klasa Circle
import math


class Circle:
    def __init__(self, radius):
        ...

    def area(self):
        ...

    def circumference(self):
        ...


c = Circle(5)
print(f"{c.area():.2f}")          # 78.54
print(f"{c.circumference():.2f}")  # 31.42

# %%
# Ćw. 5: Klasa BankAccount
class BankAccount:
    def __init__(self, owner, balance=0):
        ...

    def deposit(self, amount):
        ...

    def withdraw(self, amount):
        # hint: nie pozwalaj na wypłatę powyżej salda
        ...

    def get_balance(self):
        ...


account = BankAccount("Alice", 1000)
account.deposit(500)
print(account.get_balance())   # 1500
account.withdraw(200)
print(account.get_balance())   # 1300
account.withdraw(2000)         # Insufficient funds.
print(account.get_balance())   # 1300

# %%
# Ćw. 6: Klasa Student
class Student:
    def __init__(self, name):
        ...
        self.grades = []

    def add_grade(self, grade):
        ...

    def average(self):
        # hint: użyj sum() i len()
        ...

    def highest(self):
        ...

    def lowest(self):
        ...


s = Student("Bob")
s.add_grade(85)
s.add_grade(92)
s.add_grade(78)
print(s.average())   # 85.0
print(s.highest())   # 92
print(s.lowest())    # 78

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 🔹 Dziedziczenie i `super()`
#
# Dziedziczenie (inheritance) pozwala tworzyć nową klasę na podstawie
# istniejącej. Klasa potomna dziedziczy atrybuty i metody klasy bazowej
# i może je rozszerzać lub **nadpisywać (override)**.
#
# **Polimorfizm (polymorphism)** to zdolność różnych klas do implementowania
# tej samej metody w odmienny sposób.
#
# Funkcja `super()` pozwala odwołać się do klasy nadrzędnej:
# - `super().__init__(...)` - wywołujemy konstruktor klasy bazowej
# - `super().method()` - wywołujemy i rozszerzamy metodę klasy bazowej
#
# **MRO (Method Resolution Order)** to kolejność, w jakiej Python
# przeszukuje klasy przy wywołaniu metody. Sprawdzimy ją przez
# `ClassName.__mro__`.
#
# | | Bez `super()` | Z `super()` |
# |---|---|---|
# | Konstruktor | Powtarzamy kod inicjalizacji | `super().__init__(...)` |
# | Metoda | Nie korzystamy z logiki rodzica | Rozszerzamy logikę rodzica |
# | Wielokrotne dziedz. | Problematyczne | Obsługuje MRO poprawnie |

# %%
class Animal:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def description(self):
        return f"{self.name}, age: {self.age}"

    def sound(self):
        raise NotImplementedError("Subclass must implement sound()")


class Dog(Animal):
    def sound(self):
        return "Woof!"


class Cat(Animal):
    def sound(self):
        return "Meow!"


dog = Dog("Rex", 5)
cat = Cat("Whiskers", 3)
print(dog.description())
print(dog.sound())
print(cat.description())
print(cat.sound())

# %%
class Vehicle:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year

    def description(self):
        return f"{self.make} {self.model}, year: {self.year}"


class Car(Vehicle):
    def __init__(self, make, model, year, num_doors=4):
        super().__init__(make, model, year)
        self.num_doors = num_doors

    def description(self):
        return f"{super().description()} - {self.num_doors} doors"


class Motorcycle(Vehicle):
    def __init__(self, make, model, year, style=None):
        super().__init__(make, model, year)
        self.style = style

    def description(self):
        return f"{super().description()} - style: {self.style}"


car = Car("Toyota", "Corolla", 2020, num_doors=4)
moto = Motorcycle("Yamaha", "MT-07", 2019, "Naked")
print(car.description())
print(moto.description())

# %%
class A:
    def __init__(self):
        print("Initializing A")

    def method_a(self):
        print("Method from A")


class B(A):
    def __init__(self):
        super().__init__()
        print("Initializing B")

    def method_b(self):
        print("Method from B")


class C(B):
    def __init__(self):
        super().__init__()
        print("Initializing C")

    def method_c(self):
        print("Method from C")


obj = C()
obj.method_a()
obj.method_b()
obj.method_c()
print(C.__mro__)

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display_info(self):
        return f"Name: {self.name}, Age: {self.age}"


class Employee(Person):
    def __init__(self, name, age, employee_id):
        super().__init__(name, age)
        self.employee_id = employee_id

    def display_info(self):
        base_info = super().display_info()
        return f"{base_info}, Employee ID: {self.employee_id}"


class Manager(Employee):
    def __init__(self, name, age, employee_id, department):
        super().__init__(name, age, employee_id)
        self.department = department

    def display_info(self):
        base_info = super().display_info()
        return f"{base_info}, Department: {self.department}"


manager = Manager("Alice Smith", 40, "E12345", "Marketing")
print(manager.display_info())

# %% [markdown]
# ---

# %% [markdown]
# ### 🐍 Ćwiczenia - Dziedziczenie
#
# **Ćw. 7.** Napisz klasy `Animal` i `Dog`, gdzie `Dog` dziedziczy
# po `Animal`. Dodaj `__str__` do obu klas i nadpisz `make_sound()`
# w klasie `Dog` tak, by zwracała `"Woof! Woof!"`.
#
# **Ćw. 8.** Napisz klasę bazową `Shape` z metodą `area()` podnoszącą
# `NotImplementedError`. Utwórz podklasy `Circle` (import math) i
# `Rectangle`, które implementują `area()`.
#
# **Ćw. 9. *(Trudniejsze)*** Napisz hierarchię `Employee` -> `Manager`
# z użyciem `super()`. Manager ma dodatkowy atrybut `team` (lista).
# Dodaj `add_to_team(employee)` i `__str__` do obu klas.
# Na końcu wyświetl `Manager.__mro__`.
#
# **Ćw. 10.** Napisz klasę bazową `Vehicle` z atrybutami `make`, `model`,
# `year` i metodą `__str__`. Utwórz podklasę `ElectricCar` rozszerzającą
# konstruktor o `battery_capacity` przez `super().__init__()`,
# nadpisz `__str__`.
#
# **Ćw. 11. *(Trudniejsze)*** Napisz trzypoziomową hierarchię:
# `Animal` -> `Bird` -> `Parrot`. Każda klasa dodaje atrybut przez
# `super().__init__()` i nadpisuje `speak()`. Na końcu wyświetl
# `Parrot.__mro__`.

# %%
# Ćw. 7: Animal i Dog
class Animal:
    def __init__(self, name):
        ...

    def make_sound(self):
        return "Some generic animal sound"

    def __str__(self):
        ...


class Dog(Animal):
    def make_sound(self):
        ...

    def __str__(self):
        ...


dog = Dog("Rex")
print(dog)            # Dog(name: 'Rex')
print(dog.make_sound())  # Woof! Woof!

# %%
# Ćw. 8: Shape, Circle, Rectangle
import math


class Shape:
    def area(self):
        ...


class Circle(Shape):
    def __init__(self, radius):
        ...

    def area(self):
        ...


class Rectangle(Shape):
    def __init__(self, width, height):
        ...

    def area(self):
        ...


circle = Circle(3)
rect = Rectangle(4, 5)
print(f"Circle area: {circle.area():.2f}")    # 28.27
print(f"Rectangle area: {rect.area()}")       # 20

# %%
# Ćw. 9: Employee i Manager
class Employee:
    def __init__(self, name, salary):
        ...

    def __str__(self):
        ...


class Manager(Employee):
    def __init__(self, name, salary, department):
        ...
        self.team = []

    def add_to_team(self, employee):
        ...

    def __str__(self):
        ...


emp = Employee("Bob", 5000)
mgr = Manager("Alice", 8000, "Engineering")
mgr.add_to_team(emp)
print(emp)
print(mgr)
print(Manager.__mro__)

# %%
# Ćw. 10: Vehicle i ElectricCar
class Vehicle:
    def __init__(self, make, model, year):
        ...

    def __str__(self):
        # hint: np. 'Toyota Corolla (2020)'
        ...


class ElectricCar(Vehicle):
    def __init__(self, make, model, year, battery_capacity):
        # hint: użyj super().__init__() dla wspólnych atrybutów
        ...
        self.battery_capacity = battery_capacity

    def __str__(self):
        # hint: np. 'Tesla Model 3 (2023), battery: 75 kWh'
        ...


car = Vehicle("Toyota", "Corolla", 2020)
ev = ElectricCar("Tesla", "Model 3", 2023, 75)
print(car)   # Toyota Corolla (2020)
print(ev)    # Tesla Model 3 (2023), battery: 75 kWh

# %%
# Ćw. 11: Dziedziczenie wielopoziomowe
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return "..."


class Bird(Animal):
    def __init__(self, name, wingspan):
        # hint: użyj super().__init__()
        ...
        self.wingspan = wingspan

    def speak(self):
        return "Tweet!"


class Parrot(Bird):
    def __init__(self, name, wingspan, vocabulary):
        # hint: użyj super().__init__()
        ...
        self.vocabulary = vocabulary

    def speak(self):
        # hint: zwróć pierwsze słowo z self.vocabulary
        ...


parrot = Parrot("Polly", 30, ["Hello!", "Pretty bird!", "Squawk!"])
print(parrot.name)       # Polly
print(parrot.wingspan)   # 30
print(parrot.speak())    # Hello!
print(Parrot.__mro__)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 🔹 Hermetyzacja (enkapsulacja)
#
# Hermetyzacja (Encapsulation) polega na ukrywaniu wewnętrznej
# implementacji klasy i udostępnianiu tylko niezbędnych interfejsów.
#
# W Pythonie oznaczamy poziom dostępu przez prefiks nazwy atrybutu:
#
# | Prefiks | Przykład | Znaczenie |
# |---|---|---|
# | brak | `self.name` | publiczny - dostępny wszędzie |
# | `_` | `self._name` | chroniony - konwencja, zalecamy nie edytować |
# | `__` | `self.__name` | prywatny - name mangling, blokuje dostęp |
#
# Python stosuje **name mangling**: `__attr` staje się `_ClassName__attr`.
# Dostęp przez `obj._ClassName__attr` jest technicznie możliwy, ale
# łamie zasadę hermetyzacji.
#
# > 💡 Hermetyzacja chroni dane przed przypadkową modyfikacją z zewnątrz
# > klasy, co zwiększa bezpieczeństwo i integralność obiektów.

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance  # private

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited {amount}. New balance: {self.__balance}")
        else:
            print("Amount must be positive.")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"Withdrew {amount}. New balance: {self.__balance}")
        else:
            print("Insufficient funds or invalid amount.")

    def check_balance(self):
        return f"Balance: {self.__balance}"


account = BankAccount("Alice", 1000)
account.deposit(500)
account.withdraw(300)
print(account.check_balance())

# Direct access causes AttributeError:
# print(account.__balance)

# Name mangling - not recommended:
print(account._BankAccount__balance)

# %%
class Rectangle:
    def __init__(self, width, height):
        self.__width = width
        self.__height = height

    def set_dimensions(self, width, height):
        if width > 0 and height > 0:
            self.__width = width
            self.__height = height
        else:
            print("Width and height must be positive.")

    def area(self):
        return self.__width * self.__height

    def perimeter(self):
        return 2 * (self.__width + self.__height)

    def get_dimensions(self):
        return (self.__width, self.__height)


rect = Rectangle(5, 10)
print(f"Area: {rect.area()}")
print(f"Perimeter: {rect.perimeter()}")
print(f"Dimensions: {rect.get_dimensions()}")
rect.set_dimensions(3, 4)
print(f"New area: {rect.area()}")

# %% [markdown]
# ---

# %% [markdown]
# ### 🐍 Ćwiczenia - Hermetyzacja
#
# **Ćw. 12.** Napisz klasę `Thermometer` z prywatnym `__celsius`.
# Dodaj `get_temp()` i `set_temp(value)` - setter powinien odrzucać
# wartości poniżej -273.15 (zero bezwzględne).
#
# **Ćw. 13.** Napisz klasę `SecureCounter` z prywatnym `__count`.
# Dodaj `increment()`, `decrement()`, `reset()`, `get_count()`.
# Nie pozwalaj na spadek poniżej 0.
#
# **Ćw. 14. *(Trudniejsze)*** Napisz klasę `Person` z prywatnymi
# `__name` i `__age`. Dodaj gettery i setery z walidacją:
# - `age` musi być w zakresie 0-150
# - `name` nie może być pustym stringiem
#
# **Ćw. 15.** Napisz klasę `Inventory` z chronionym atrybutem `_items`
# (pusta lista) i `_capacity = 10`. Dodaj `add_item(item)` (blokuj gdy
# pojemność przekroczona), `remove_item(item)` i `get_items()`.
# Na końcu wyświetl `inv._items` bezpośrednio.
#
# **Ćw. 16.** Napisz klasę `Safe` z prywatnym `__code`. Dodaj
# `check_code(code)` (zwraca `True`/`False`) i `change_code(old, new)`
# (zmienia kod tylko gdy `old` jest poprawny). Na końcu wyświetl
# wartość przez name mangling: `safe._Safe__code`.
#
# **Ćw. 17. *(Trudniejsze)*** Napisz klasę `CreditCard` z prywatnymi
# `__number`, `__balance = 0` i `__limit`. Dodaj:
# - `charge(amount)` - dolicza do salda, blokuj jeśli przekroczy limit
# - `get_balance()` - zwraca saldo
# - `get_masked_number()` - np. `"****1234"` (ostatnie 4 cyfry)

# %%
# Ćw. 12: Thermometer
class Thermometer:
    def __init__(self, celsius):
        self.__celsius = celsius

    def get_temp(self):
        ...

    def set_temp(self, value):
        # hint: odrzuć wartości < -273.15
        ...


t = Thermometer(20)
print(t.get_temp())   # 20
t.set_temp(37)
print(t.get_temp())   # 37
t.set_temp(-300)      # Invalid temperature.
print(t.get_temp())   # 37

# %%
# Ćw. 13: SecureCounter
class SecureCounter:
    def __init__(self):
        self.__count = 0

    def increment(self):
        ...

    def decrement(self):
        # hint: nie pozwalaj na wartości ujemne
        ...

    def reset(self):
        ...

    def get_count(self):
        ...


counter = SecureCounter()
counter.increment()
counter.increment()
counter.increment()
print(counter.get_count())   # 3
counter.decrement()
print(counter.get_count())   # 2
counter.reset()
print(counter.get_count())   # 0
counter.decrement()
print(counter.get_count())   # 0 (not negative)

# %%
# Ćw. 14: Person z walidacją
class Person:
    def __init__(self, name, age):
        ...

    def get_name(self):
        ...

    def set_name(self, value):
        # hint: sprawdź czy value nie jest pusty
        ...

    def get_age(self):
        ...

    def set_age(self, value):
        # hint: sprawdź zakres 0-150
        ...


p = Person("Alice", 30)
print(p.get_name())   # Alice
print(p.get_age())    # 30
p.set_age(200)        # Invalid age.
p.set_name("")       # Invalid name.
print(p.get_age())    # 30

# %%
# Ćw. 15: Inventory z atrybutem chronionym
class Inventory:
    def __init__(self):
        self._items = []
        self._capacity = 10

    def add_item(self, item):
        # hint: sprawdź czy len(_items) < _capacity
        ...

    def remove_item(self, item):
        ...

    def get_items(self):
        ...


inv = Inventory()
inv.add_item("sword")
inv.add_item("shield")
print(inv.get_items())   # ['sword', 'shield']
inv.remove_item("sword")
print(inv.get_items())   # ['shield']
# Dostęp do chronionego atrybutu (możliwy, ale niezalecany):
print(inv._items)        # ['shield']

# %%
# Ćw. 16: Safe - name mangling
class Safe:
    def __init__(self, code):
        self.__code = code

    def check_code(self, code):
        ...

    def change_code(self, old_code, new_code):
        # hint: zmień tylko gdy old_code jest poprawny
        ...


safe = Safe("1234")
print(safe.check_code("0000"))   # False
print(safe.check_code("1234"))   # True
safe.change_code("1234", "5678")
print(safe.check_code("5678"))   # True
# Name mangling - dostęp przez _ClassName__attr:
print(safe._Safe__code)           # 5678

# %%
# Ćw. 17: CreditCard
class CreditCard:
    def __init__(self, number, limit):
        self.__number = number
        self.__balance = 0
        self.__limit = limit

    def charge(self, amount):
        # hint: sprawdź czy balance + amount nie przekroczy limitu
        ...

    def get_balance(self):
        ...

    def get_masked_number(self):
        # hint: f'****{self.__number[-4:]}'
        ...


card = CreditCard("1234567890001234", 5000)
print(card.get_masked_number())   # ****1234
card.charge(1000)
print(card.get_balance())         # 1000
card.charge(5000)                 # Limit exceeded.
print(card.get_balance())         # 1000

# %% [markdown]
# ---

# %% [markdown]
# ## 4. 🔹 Metody specjalne (dunder)
#
# Metody dunder (double underscore) zaczynają się i kończą `__`.
# Definiują zachowanie obiektów w różnych kontekstach Pythona -
# umożliwiają **przeciążanie operatorów (operator overloading)**.
#
# | Metoda | Wywołanie | Opis |
# |---|---|---|
# | `__init__` | `obj = Class()` | konstruktor obiektu |
# | `__str__` | `str(obj)`, `print(obj)` | reprezentacja dla użytkownika |
# | `__repr__` | `repr(obj)` | reprezentacja dla dewelopera |
# | `__add__` | `obj1 + obj2` | operator dodawania `+` |
# | `__eq__` | `obj1 == obj2` | operator równości `==` |
# | `__len__` | `len(obj)` | długość obiektu |
#
# > 💡 `__str__` jest czytelne dla użytkownika, `__repr__` precyzyjne
# > dla dewelopera. Jeśli zdefiniujemy tylko `__repr__`, Python użyje
# > go też dla `str()`. Definiujemy oba, gdy potrzebujemy różnych wersji.

# %%
class PersonWithStr:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"Person(Name: {self.name}, Age: {self.age})"

    def __repr__(self):
        return f"Person(name={self.name!r}, age={self.age})"


class PersonNoStr:
    def __init__(self, name, age):
        self.name = name
        self.age = age


p1 = PersonWithStr("Alice", 30)
p2 = PersonNoStr("Bob", 27)
print(p1)          # Person(Name: Alice, Age: 30)
print(repr(p1))    # Person(name='Alice', age=30)
print(p2)          # <__main__.PersonNoStr object at 0x...>

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __repr__(self):
        return f"Vector(x={self.x}, y={self.y})"

    def __str__(self):
        return f"({self.x}, {self.y})"

    def __add__(self, other):
        if isinstance(other, Vector):
            return Vector(self.x + other.x, self.y + other.y)
        return NotImplemented

    def __eq__(self, other):
        if isinstance(other, Vector):
            return self.x == other.x and self.y == other.y
        return False


v1 = Vector(2, 3)
v2 = Vector(4, 5)
print(v1)                   # (2, 3)
print(repr(v1))             # Vector(x=2, y=3)
print(v1 + v2)              # (6, 8)
print(v1 == Vector(2, 3))   # True
print(v1 == v2)             # False

# %%
class Matrix:
    def __init__(self, rows):
        self.rows = rows
        self.num_rows = len(rows)
        self.num_cols = len(rows[0]) if rows else 0

    def __repr__(self):
        return f"Matrix(rows={self.rows})"

    def __str__(self):
        return '\n'.join(['\t'.join(map(str, row)) for row in self.rows])

    def __add__(self, other):
        if isinstance(other, Matrix) and (
            self.num_rows == other.num_rows
            and self.num_cols == other.num_cols
        ):
            result = [
                [self.rows[i][j] + other.rows[i][j]
                 for j in range(self.num_cols)]
                for i in range(self.num_rows)
            ]
            return Matrix(result)
        return NotImplemented

    def __mul__(self, other):
        if isinstance(other, (int, float)):
            result = [[el * other for el in row] for row in self.rows]
            return Matrix(result)
        if isinstance(other, Matrix) and self.num_cols == other.num_rows:
            result = [
                [sum(self.rows[i][k] * other.rows[k][j]
                     for k in range(self.num_cols))
                 for j in range(other.num_cols)]
                for i in range(self.num_rows)
            ]
            return Matrix(result)
        return NotImplemented


m1 = Matrix([[1, 2], [3, 4]])
m2 = Matrix([[5, 6], [7, 8]])
print("m1 + m2:")
print(m1 + m2)
print("m1 * 2:")
print(m1 * 2)
print("m1 * m2:")
print(m1 * m2)

# %% [markdown]
# ---

# %% [markdown]
# ### 🐍 Ćwiczenia - Metody specjalne
#
# **Ćw. 18.** Napisz klasę `Point` reprezentującą punkt na płaszczyźnie.
# Dodaj `__str__` (np. `"Point(1, 2)"`), `__repr__` i `__eq__`.
#
# **Ćw. 19.** Napisz klasę `Fraction` (ułamek) z atrybutami `numerator`
# i `denominator`. Dodaj `__str__` (np. `"3/4"`) i `__add__`
# (wzór: a/b + c/d = (a*d + b*c) / (b*d)).
#
# **Ćw. 20. *(Trudniejsze)*** Napisz klasę `Bag` (torba przedmiotów):
# - `add(item)` - dodaje przedmiot do listy
# - `__len__` - zwraca liczbę przedmiotów
# - `__add__` - łączy dwie torby w nową
# - `__str__` - wyświetla zawartość, np. `"Bag: apple, banana"`
#
# **Ćw. 21.** Napisz klasę `Temperature` z atrybutem `celsius`. Dodaj
# `__str__` (np. `"25°C"`), `__repr__` (np. `"Temperature(25)"`) i
# `__eq__` porównujący wartości.
#
# **Ćw. 22.** Napisz klasę `Vector` z atrybutami `x` i `y`. Dodaj
# `__str__`, `__add__` (dodawanie wektorów), `__mul__` (mnożenie przez
# skalar) i `__eq__`.
#
# **Ćw. 23. *(Trudniejsze)*** Napisz klasę `Stack` (stos) z prywatną
# listą `_items`. Dodaj `push(item)`, `pop()` (zwraca i usuwa ostatni
# element, `None` jeśli pusty), `__len__`,
# `__str__` (np. `"Stack[1, 2, 3]"`) i `__eq__`.

# %%
# Ćw. 18: Point
class Point:
    def __init__(self, x, y):
        ...

    def __str__(self):
        ...

    def __repr__(self):
        ...

    def __eq__(self, other):
        ...


p1 = Point(1, 2)
p2 = Point(1, 2)
p3 = Point(3, 4)
print(p1)           # Point(1, 2)
print(repr(p1))     # Point(x=1, y=2)
print(p1 == p2)     # True
print(p1 == p3)     # False

# %%
# Ćw. 19: Fraction
class Fraction:
    def __init__(self, numerator, denominator):
        ...

    def __str__(self):
        # hint: f"{self.numerator}/{self.denominator}"
        ...

    def __add__(self, other):
        # hint: a/b + c/d = (a*d + b*c) / (b*d)
        ...


f1 = Fraction(1, 2)
f2 = Fraction(1, 4)
f3 = f1 + f2
print(f1)   # 1/2
print(f2)   # 1/4
print(f3)   # 6/8

# %%
# Ćw. 20: Bag
class Bag:
    def __init__(self):
        self.items = []

    def add(self, item):
        ...

    def __len__(self):
        ...

    def __add__(self, other):
        # hint: utwórz nową torbę, dodaj items z obu
        ...

    def __str__(self):
        ...


bag1 = Bag()
bag1.add("apple")
bag1.add("banana")
bag2 = Bag()
bag2.add("cherry")
print(len(bag1))     # 2
bag3 = bag1 + bag2
print(len(bag3))     # 3
print(bag3)          # Bag: apple, banana, cherry

# %%
# Ćw. 21: Klasa Temperature
class Temperature:
    def __init__(self, celsius):
        ...

    def __str__(self):
        # hint: np. '25°C'
        ...

    def __repr__(self):
        # hint: np. 'Temperature(25)'
        ...

    def __eq__(self, other):
        ...


t1 = Temperature(25)
t2 = Temperature(25)
t3 = Temperature(100)
print(t1)           # 25°C
print(repr(t1))     # Temperature(25)
print(t1 == t2)     # True
print(t1 == t3)     # False

# %%
# Ćw. 22: Klasa Vector
class Vector:
    def __init__(self, x, y):
        ...

    def __str__(self):
        ...

    def __add__(self, other):
        ...

    def __mul__(self, scalar):
        # hint: skaluj każdą współrzędną przez scalar
        ...

    def __eq__(self, other):
        ...


v1 = Vector(1, 2)
v2 = Vector(3, 4)
print(v1)                     # Vector(1, 2)
print(v1 + v2)                # Vector(4, 6)
print(v1 * 3)                 # Vector(3, 6)
print(v1 == Vector(1, 2))     # True

# %%
# Ćw. 23: Klasa Stack
class Stack:
    def __init__(self):
        self._items = []

    def push(self, item):
        ...

    def pop(self):
        # hint: usuń i zwróć ostatni element, lub None jeśli pusty
        ...

    def __len__(self):
        ...

    def __str__(self):
        # hint: np. 'Stack[1, 2, 3]' (lewy=dół, prawy=góra)
        ...

    def __eq__(self, other):
        ...


s1 = Stack()
s1.push(1)
s1.push(2)
s1.push(3)
s2 = Stack()
s2.push(1)
s2.push(2)
s2.push(3)
print(len(s1))      # 3
print(s1)           # Stack[1, 2, 3]
print(s1 == s2)     # True
print(s1.pop())     # 3
print(len(s1))      # 2

# %% [markdown]
# ---

# %% [markdown]
# ## 5. 🔹 Metody klasowe: `self` vs `cls`
#
# W Pythonie wyróżniamy trzy rodzaje metod:
#
# | Rodzaj | Dekorator | Pierwszy param | Dostęp do |
# |---|---|---|---|
# | Metoda instancji | brak | `self` | instancji i klasy |
# | Metoda klasowa | `@classmethod` | `cls` | tylko klasy |
# | Metoda statyczna | `@staticmethod` | brak | brak |
#
# - **`self`** - odwołanie do konkretnego obiektu (instancji)
# - **`cls`** - odwołanie do samej klasy (nie do instancji)
#
# Metody klasowe (`@classmethod`) stosujemy gdy:
# - operujemy na atrybutach wspólnych dla wszystkich instancji
# - tworzymy **alternatywne konstruktory** (factory methods)
#
# > 💡 Atrybuty klasy (class attributes) są wspólne dla wszystkich
# > instancji - zmiana przez jedną instancję widoczna jest dla wszystkich.

# %%
class Car:
    def __init__(self, make, model):
        self.make = make    # attribute of this specific instance
        self.model = model

    def description(self):
        # self refers to the specific car object
        return f"{self.make} {self.model}"


car1 = Car("Toyota", "Corolla")
car2 = Car("Honda", "Civic")
print(car1.description())  # Toyota Corolla
print(car2.description())  # Honda Civic

# %%
class Car:
    car_count = 0  # class attribute - shared by all instances

    def __init__(self, make, model):
        self.make = make
        self.model = model
        Car.car_count += 1

    @classmethod
    def get_count(cls):
        return cls.car_count


car1 = Car("Toyota", "Corolla")
car2 = Car("Honda", "Civic")
print(Car.get_count())   # 2
car3 = Car("BMW", "3 Series")
print(Car.get_count())   # 3

# %%
class Temperature:
    def __init__(self, celsius):
        self.celsius = celsius

    @classmethod
    def from_fahrenheit(cls, fahrenheit):
        celsius = (fahrenheit - 32) * 5 / 9
        return cls(celsius)

    @classmethod
    def from_kelvin(cls, kelvin):
        celsius = kelvin - 273.15
        return cls(celsius)

    def __str__(self):
        return f"{self.celsius:.2f}°C"


t1 = Temperature(00)
t2 = Temperature.from_fahrenheit(212)
t3 = Temperature.from_kelvin(373.15)
print(t1)   # 00.00°C
print(t2)   # 00.00°C
print(t3)   # 00.00°C

# %% [markdown]
# ---

# %% [markdown]
# ### 🐍 Ćwiczenia - Metody klasowe
#
# **Ćw. 24.** Napisz klasę `Counter` z atrybutem klasy `count = 0`.
# Każde wywołanie `__init__` zwiększa licznik. Dodaj
# `@classmethod get_count()` i `@classmethod reset_count()`.
#
# **Ćw. 25.** Rozszerz klasę `Rectangle` z ćw. 1 o metodę klasową
# `from_square(cls, side)`, która tworzy prostokąt o równych bokach.
#
# **Ćw. 26. *(Trudniejsze)*** Napisz klasę `Pizza` z atrybutami
# `size` i `toppings`. Dodaj `@classmethod` factory methods:
# - `margherita(cls)` - rozmiar `"M"`, składniki `["tomato",
#   "mozzarella"]`
# - `pepperoni(cls)` - rozmiar `"L"`, składniki `["tomato",
#   "mozzarella", "pepperoni"]`
#
# Dodaj `__str__` wyświetlający rozmiar i składniki.
#
# **Ćw. 27.** Napisz klasę `TemperatureConverter` z atrybutem `celsius`.
# Dodaj metodę instancji `describe()` (np. `"100°C"`) oraz dwie metody
# statyczne: `celsius_to_fahrenheit(c)` i `fahrenheit_to_celsius(f)`.
#
# **Ćw. 28. *(Trudniejsze)*** Napisz klasę `User` z atrybutem klasy
# `_user_count = 0`. Konstruktor przyjmuje `username` i `email`
# i zwiększa licznik. Dodaj:
# - `@classmethod get_user_count()` - zwraca liczbę użytkowników
# - `@classmethod create_guest(cls)` - tworzy użytkownika `"guest"`
#   z emailem `"guest@example.com"`
# - `@staticmethod is_valid_email(email)` - `True` jeśli email zawiera
#   `"@"` i `"."`, inaczej `False`

# %%
# Ćw. 24: Counter z metodą klasową
class Counter:
    count = 0

    def __init__(self):
        ...

    @classmethod
    def get_count(cls):
        ...

    @classmethod
    def reset_count(cls):
        ...


c1 = Counter()
c2 = Counter()
c3 = Counter()
print(Counter.get_count())   # 3
Counter.reset_count()
print(Counter.get_count())   # 0

# %%
# Ćw. 25: Rectangle z factory method
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    @classmethod
    def from_square(cls, side):
        # hint: utwórz Rectangle z width == height == side
        ...


rect = Rectangle(4, 6)
square = Rectangle.from_square(5)
print(rect.area())                  # 24
print(square.area())                # 25
print(square.width, square.height)  # 5 5

# %%
# Ćw. 26: Pizza z factory methods
class Pizza:
    def __init__(self, size, toppings):
        self.size = size
        self.toppings = toppings

    @classmethod
    def margherita(cls):
        ...

    @classmethod
    def pepperoni(cls):
        ...

    def __str__(self):
        ...


p1 = Pizza.margherita()
p2 = Pizza.pepperoni()
print(p1)   # Pizza M: tomato, mozzarella
print(p2)   # Pizza L: tomato, mozzarella, pepperoni

# %%
# Ćw. 27: TemperatureConverter
class TemperatureConverter:
    def __init__(self, celsius):
        ...

    def describe(self):
        # hint: metoda instancji - zwraca np. '100°C'
        ...

    @staticmethod
    def celsius_to_fahrenheit(c):
        # hint: (c * 9/5) + 32
        ...

    @staticmethod
    def fahrenheit_to_celsius(f):
        # hint: (f - 32) * 5/9
        ...


t = TemperatureConverter(100)
print(t.describe())                                    # 100°C
print(TemperatureConverter.celsius_to_fahrenheit(100)) # 212.0
print(TemperatureConverter.fahrenheit_to_celsius(32))  # 0.0

# %%
# Ćw. 28: Klasa User
class User:
    _user_count = 0

    def __init__(self, username, email):
        ...
        User._user_count += 1

    def __str__(self):
        ...

    @classmethod
    def get_user_count(cls):
        ...

    @classmethod
    def create_guest(cls):
        # hint: utwórz użytkownika 'guest' z 'guest@example.com'
        ...

    @staticmethod
    def is_valid_email(email):
        # hint: sprawdź czy '@' i '.' są w emailu
        ...


u1 = User("alice", "alice@example.com")
u2 = User.create_guest()
print(User.get_user_count())                  # 2
print(u1)                                     # User: alice (alice@example.com)
print(u2)                                     # User: guest (guest@example.com)
print(User.is_valid_email("test@test.com"))   # True
print(User.is_valid_email("invalid"))         # False
