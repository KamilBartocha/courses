# %% [markdown]
# # 04 Python intermediate
# ## Wirtualne środowisko i Debugger
#
# _Kamil Bartocha_ - wersja 2.0

# %% [markdown]
# ## Rozkład jazdy
#
# 1. 🔹 **Wirtualne środowisko (`venv`)** - izolacja zależności projektu
# 2. 🔹 **`requirements.txt`** - zarządzanie i reprodukcja środowiska
# 3. 🔹 **Debugger** - krok po kroku przez kod, punkty przerwania
#
# 🐍 Każda sekcja zawiera ćwiczenia.

# %% [markdown]
# ---

# %% [markdown]
# ## 1. 🔹 Wirtualne środowisko (`venv`)
#
# **Wirtualne środowisko (virtual environment)** to odizolowana
# instalacja Pythona z własnym zestawem pakietów. Każdy projekt
# dostaje swoje własne środowisko, niezależne od innych projektów
# i od globalnej instalacji Pythona.
#
# | | Bez `venv` | Z `venv` |
# |---|---|---|
# | Pakiety | globalne, wspólne | lokalne, per projekt |
# | Konflikty wersji | możliwe | brak |
# | Przenoszalność | trudna | łatwa przez `requirements.txt` |
# | Izolacja | brak | pełna |
#
# > 💡 `venv` jest wbudowany w Pythona 3.3+ - nie wymagamy
# > dodatkowej instalacji. Używamy `python -m venv`.

# %% [markdown]
# ### Podstawowe polecenia `venv`
#
# **Tworzenie środowiska:**
# ```bash
# python -m venv nazwa_srodowiska
# ```
#
# **Aktywacja:**
# ```bash
# # macOS / Linux
# source nazwa_srodowiska/bin/activate
#
# # Windows
# nazwa_srodowiska\Scripts\activate
# ```
#
# **Instalacja pakietów (gdy środowisko aktywne):**
# ```bash
# pip install nazwa_pakietu
# pip install requests==2.28.0   # konkretna wersja
# ```
#
# **Dezaktywacja:**
# ```bash
# deactivate
# ```
#
# Po aktywacji w terminalu pojawia się prefix `(nazwa_srodowiska)`
# przed ścieżką - oznacza to, że jesteśmy wewnątrz środowiska.

# %% [markdown]
# ### Struktura katalogu projektu
#
# ```
# project_root/
# ├── venv/                   <- środowisko (nie commitujemy!)
# │   ├── bin/
# │   ├── lib/
# │   │   └── pythonX.Y/
# │   │       └── site-packages/
# │   └── pyvenv.cfg
# ├── src/
# │   └── main.py
# ├── requirements.txt        <- commitujemy
# ├── .gitignore              <- dodajemy venv/ do .gitignore
# └── README.md
# ```
#
# > 💡 Katalogu `venv/` nigdy nie wrzucamy do repozytorium git.
# > Dodajemy go do `.gitignore`. Inni deweloperzy odtworzą środowisko
# > przez `pip install -r requirements.txt`.

# %% [markdown]
# ---

# %% [markdown]
# ### 🐍 Ćwiczenia - `venv`
#
# **Ćw. 1.** Wpisz polecenia (w komentarzach lub terminalu), które:
# - tworzą środowisko o nazwie `myenv`
# - aktywują je (macOS/Linux)
# - instalują pakiet `requests`
# - dezaktywują środowisko
#
# **Ćw. 2.** Masz dwa projekty:
# - `project_old` wymaga `selenium==3.141.0`
# - `project_new` wymaga `selenium==4.18.0`
#
# Napisz polecenia tworzące dwa **oddzielne** środowiska dla obu
# projektów i instalujące właściwe wersje.
#
# **Ćw. 3. *(Trudniejsze)*** W Pythonie możemy sprawdzić, które
# środowisko jest aktywne przez `sys.prefix`. Uruchom poniższy
# kod i sprawdź, czy wirtualne środowisko jest aktywne.
#
# **Ćw. 4.** Utwórz zawartość pliku `.gitignore` dla projektu Python.
# Uzupełnij listę wpisów, które wykluczą katalog wirtualnego
# środowiska, katalogi cache oraz skompilowane pliki Pythona.
#
# **Ćw. 5. *(Trudniejsze)*** Zapisz jako komentarze kompletny przepływ
# pracy przy tworzeniu nowego projektu Python: utwórz katalog projektu,
# wirtualne środowisko, zainstaluj zależności (`requests`, `pytest`),
# wygeneruj `requirements.txt`, a na końcu dezaktywuj środowisko.

# %%
# Ćw. 1: Wpisz polecenia terminala jako komentarze
# Tworzenie:
# ...

# Aktywacja (macOS/Linux):
# ...

# Instalacja requests:
# ...

# Dezaktywacja:
# ...

# %%
# Ćw. 2: Dwa projekty, dwie wersje selenium
# project_old - selenium 3.141.0:
# ...

# project_new - selenium 4.18.0:
# ...

# %%
# Ćw. 3: Sprawdź aktywne środowisko
import sys

print(sys.prefix)       # ścieżka do aktywnego środowiska
print(sys.executable)  # ścieżka do używanego interpretera

# Czy jesteśmy w venv?
in_venv = sys.prefix != sys.base_prefix
print(f"W venv: {in_venv}")

# %%
# Ćw. 4: Utwórz zawartość pliku .gitignore dla projektu Python
# Uzupełnij listę, dodając wpisy wykluczające:
# - katalog wirtualnego środowiska o nazwie 'myenv'
# - katalogi __pycache__
# - skompilowane pliki Pythona (*.pyc)

gitignore_entries = [
    ...  # uzupełnij
]

print("\n".join(gitignore_entries))
# Oczekiwany wynik powinien zawierać m.in.: myenv/, __pycache__/, *.pyc

# %%
# Ćw. 5 *(Trudniejsze)*: Zapisz jako komentarze kompletny przepływ pracy
# przy tworzeniu nowego projektu Python o nazwie 'my_api':
# 1. Utwórz katalog projektu
# 2. Wejdź do katalogu i utwórz wirtualne środowisko 'venv'
# 3. Aktywuj środowisko (macOS/Linux)
# 4. Zainstaluj zależności: requests oraz pytest
# 5. Wygeneruj plik requirements.txt
# 6. Dezaktywuj środowisko

# mkdir my_api && cd my_api
# ...
# ...
# ...
# ...
# ...

print("Przepływ pracy kompletny!")

# %% [markdown]
# ---

# %% [markdown]
# ## 2. 🔹 `requirements.txt`
#
# Plik `requirements.txt` to lista pakietów wymaganych przez projekt.
# Pozwala odtworzyć identyczne środowisko na innej maszynie.
#
# **Tworzenie `requirements.txt` z aktywnego środowiska:**
# ```bash
# pip freeze > requirements.txt
# ```
#
# **Instalacja wszystkich pakietów z pliku:**
# ```bash
# pip install -r requirements.txt
# ```
#
# **Format pliku:**
# ```
# requests==2.31.0
# selenium==4.18.0
# pytest>=7.0.0
# ```
#
# | Operator | Znaczenie | Przykład |
# |---|---|---|
# | `==` | dokładna wersja | `requests==2.31.0` |
# | `>=` | co najmniej wersja | `pytest>=7.0.0` |
# | `~=` | kompatybilna wersja | `flask~=2.3.0` |
# | brak | najnowsza | `requests` |

# %% [markdown]
# ### Przykład: migracja Selenium 3 → 4
#
# Aktualizacja biblioteki może wymagać zmian w kodzie. Wirtualne
# środowiska pozwalają testować nową wersję bez ruszania starego kodu.

# %%
# Selenium 3 - stara składnia (find_element_by_*)
# from selenium import webdriver
# from selenium.webdriver.common.keys import Keys
#
# driver = webdriver.Chrome()
# driver.get('https://www.google.com')
# search_box = driver.find_element_by_name('q')   # usunięte w v4
# search_box.send_keys('Selenium Python')
# search_box.send_keys(Keys.RETURN)
# first_result = driver.find_element_by_css_selector('h3')  # usunięte
# driver.quit()

# %%
# Selenium 4 - nowa składnia (find_element z By)
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
#
# driver = webdriver.Chrome()
# driver.get('https://www.google.com')
# search_box = driver.find_element(By.NAME, 'q')        # nowa składnia
# search_box.send_keys('Selenium Python')
# search_box.send_keys(Keys.RETURN)
# first_result = driver.find_element(By.CSS_SELECTOR, 'h3')
# driver.quit()

# %% [markdown]
# > 💡 W Selenium 4 metody `find_element_by_*` zostały usunięte.
# > Używamy teraz `find_element(By.NAME, ...)`,
# > `find_element(By.CSS_SELECTOR, ...)` itd.

# %% [markdown]
# ### 🐍 Ćwiczenia - `requirements.txt`
#
# **Ćw. 6.** Odczytaj poniższy plik `requirements.txt` i odpowiedz:
# - Która biblioteka ma określoną dokładną wersję?
# - Która ma wersję minimalną?
# - Jakim poleceniem zainstalujemy wszystkie pakiety?
#
# ```
# requests==2.31.0
# pytest>=7.4.0
# selenium~=4.18.0
# black
# ```
#
# **Ćw. 7.** Sprawdź zainstalowane pakiety w aktywnym środowisku
# i ich wersje. Wygeneruj `requirements.txt`.
#
# **Ćw. 8. *(Trudniejsze)*** Odczytaj wersję zainstalowanego pakietu
# programowo przez `importlib.metadata`.
#
# **Ćw. 9. *(Trudniejsze)*** Napisz funkcję, która parsuje zawartość
# pliku `requirements.txt` i zwraca slownik `{nazwa: specyfikator}`.
# Dla pakietów bez wersji wartość powinna być `None`.

# %% [markdown]
# # Ćw. 6: Odpowiedzi jako komentarze
# # Dokładna wersja (==): ...
# # Wersja minimalna (>=): ...
# # Polecenie instalacji: ...

# %%
# Ćw. 7: Lista zainstalowanych pakietów
# W terminalu:
# pip list              - wszystkie zainstalowane pakiety
# pip freeze            - format requirements.txt
# pip freeze > requirements.txt   - zapis do pliku

# Programowo w Pythonie:
import subprocess
result = subprocess.run(['pip', 'list'], capture_output=True, text=True)
print(result.stdout[:500])   # pierwsze 500 znaków

# %%
# Ćw. 8: Wersja pakietu przez importlib.metadata
import importlib.metadata

def get_version(package_name):
    try:
        return importlib.metadata.version(package_name)
    except importlib.metadata.PackageNotFoundError:
        return f"{package_name} not installed"


print(get_version("pip"))
print(get_version("requests"))
print(get_version("nonexistent-package"))

# %%
# Ćw. 9 *(Trudniejsze)*: Parsowanie requirements.txt
# Napisz funkcję, która parsuje zawartość pliku requirements.txt
# i zwraca slownik {nazwa_pakietu: specyfikator_wersji}.
# Dla pakietów bez wersji wartość powinna być None.

requirements_txt = "requests==2.31.0\npytest>=7.4.0\nselenium~=4.18.0\nblack\n"

def parse_requirements(content):
    result = {}
    for line in content.strip().split('\n'):
        ...
    return result


packages = parse_requirements(requirements_txt)
print(packages)
# {'requests': '==2.31.0', 'pytest': '>=7.4.0', 'selenium': '~=4.18.0', 'black': None}

# %%
# Ćw. 6: Wersja pakietu przez importlib.metadata
import importlib.metadata

def get_version(package_name):
    try:
        return importlib.metadata.version(package_name)
    except importlib.metadata.PackageNotFoundError:
        return f"{package_name} not installed"


print(get_version("pip"))
print(get_version("requests"))
print(get_version("nonexistent-package"))

# %% [markdown]
# ---

# %% [markdown]
# ## 3. 🔹 Debugger
#
# **Debugger** to narzędzie do analizy kodu krok po kroku. Pozwala
# zatrzymać program w dowolnym miejscu i zbadać stan zmiennych.
#
# ### Kluczowe operacje
#
# | Operacja | Skrót (VS Code) | Opis |
# |---|---|---|
# | Breakpoint | `F9` | zatrzymaj program w tej linii |
# | Continue | `F5` | kontynuuj do następnego breakpointa |
# | Step Over | `F10` | wykonaj linię, nie wchodź do funkcji |
# | Step Into | `F11` | wejdź do wnętrza funkcji |
# | Step Out | `Shift+F11` | wyjdź z bieżącej funkcji |
#
# W Pythonie możemy też wstawić punkt przerwania programowo:
#
# ```python
# breakpoint()   # Python 3.7+ - otwiera pdb
# ```
#
# > 💡 Debugger jest szybszy niż `print()` przy szukaniu błędów.
# > Pozwala sprawdzić stan **wszystkich** zmiennych naraz, bez
# > modyfikowania kodu.

# %%
# Przykład - śledzimy pętlę krok po kroku
word = 'debugging'
letter = 'g'
count = 0

for char in word:
    if char == letter:
        count += 1

print(f"Letter '{letter}' appears {count} times in '{word}'.")

# Umieść breakpoint na linii 'for char in word:' i obserwuj
# jak zmienia się 'char' i 'count' w każdej iteracji.

# %% [markdown]
# ### 🐍 Ćwiczenia - Debugger
#
# Poniższe funkcje zawierają błędy. Uruchom je z debuggerem
# (lub przez analizę), znajdź i napraw każdy błąd.
#
# **Ćw. 10.** Funkcja ma zwracać sumę liczb od 1 do n.
# Wynik dla `n=5` powinien być `15`.
#
# **Ćw. 11.** Funkcja ma zwracać liczbę samogłosek w słowie.
# Dla `"hello"` wynik powinien być `2`.
#
# **Ćw. 12. *(Trudniejsze)*** Funkcja ma zwracać listę liczb
# pierwszych do `n`. Dla `n=10` wynik: `[2, 3, 5, 7]`.
#
# **Ćw. 13.** Dodaj wywołanie `breakpoint()` wewnątrz pętli
# funkcji `find_first_negative`. Uruchom w terminalu i obserwuj
# wartości zmiennych w kolejnych iteracjach (pdb: `n`, `p zmienna`).
#
# **Ćw. 14. *(Trudniejsze)*** Ustaw breakpoint na wywolaniu `process(data)`
# i uzyj Step Into (F11), aby wejsc do funkcji `process()`, a nastepnie
# do `validate()`. Znajdz i napraw blad w logice walidacji.

# %% [markdown]
# # Ćw. 10: Znajdź i napraw błąd
# def sum_to_n(n):
#     total = 0
#     for i in range(n):   # błąd tutaj
#         total += i
#     return total
#
#
# print(sum_to_n(5))   # powinno być 15, jest: ?

# %% [markdown]
# # Ćw. 11: Znajdź i napraw błąd
# def count_vowels(word):
#     vowels = 'aeiou'
#     count = 0
#     for char in word:
#         if char in vowels:   # sprawdź: case-sensitive?
#             count == 1       # błąd tutaj
#     return count
#
#
# print(count_vowels("hello"))   # powinno być 2, jest: ?
# print(count_vowels("APPLE"))   # powinno być 2, jest: ?

# %%
# Ćw. 12: Znajdź i napraw błąd (liczby pierwsze)
def primes_up_to(n):
    primes = []
    for num in range(2, n):   # sprawdź: czy n jest wliczone?
        is_prime = True
        for divisor in range(2, num):
            if num % divisor == 0:
                is_prime = False
        if is_prime:
            primes.append(num)
    return primes


print(primes_up_to(10))   # powinno być [2, 3, 5, 7]
print(primes_up_to(11))   # powinno być [2, 3, 5, 7, 11]

# %%
# Ćw. 14 *(Trudniejsze)*: Step Into - debugowanie zagnieżdżonych funkcji.
# Ustaw breakpoint na linii 'result = process(data)', naciśnij F11
# (Step Into), aby wejść do process(), potem do validate().
# Znajdź i napraw błąd w logice walidacji.

def validate(value):
    return value > 0   # czy to poprawna walidacja dla wszystkich przypadków?

def process(numbers):
    return [n * 2 for n in numbers if validate(n)]

data = [-3, 0, 5, -1, 8, 2]
# breakpoint()   # ustaw breakpoint tutaj i użyj Step Into (F11)
result = process(data)
print(result)   # powinno być [10, 16, 4] (tylko dodatnie * 2)

# %%
# Ćw. 13: Dodaj breakpoint() do poniższej funkcji i uruchom w terminalu.
# W debuggerze pdb:
#   n      - następna linia (step over)
#   p num  - wypisz wartość zmiennej
#   q      - wyjdź

def find_first_negative(numbers):
    for i, num in enumerate(numbers):
        # breakpoint()   # odkomentuj i uruchom: python3 <plik.py>
        if num < 0:
            return i
    return -1

data = [5, 3, -2, 8, -1, 4]
idx = find_first_negative(data)
print(f"Pierwszy ujemny na indeksie: {idx}")   # powinno być 2

# Odpowiedz jako komentarze:
# Ile razy zatrzyma się breakpoint? ...
# Jakie kolejne wartości przyjmuje 'num'? ...

# %%
# Ćw. 8: Znajdź i napraw błąd
def count_vowels(word):
    vowels = 'aeiou'
    count = 0
    for char in word:
        if char in vowels:   # sprawdź: case-sensitive?
            count == 1       # błąd tutaj
    return count


print(count_vowels("hello"))   # powinno być 2, jest: ?
print(count_vowels("APPLE"))   # powinno być 2, jest: ?

# %%
# Ćw. 9: Znajdź i napraw błąd (liczby pierwsze)
def primes_up_to(n):
    primes = []
    for num in range(2, n):   # sprawdź: czy n jest wliczone?
        is_prime = True
        for divisor in range(2, num):
            if num % divisor == 0:
                is_prime = False
        if is_prime:
            primes.append(num)
    return primes


print(primes_up_to(10))   # powinno być [2, 3, 5, 7]
print(primes_up_to(11))   # powinno być [2, 3, 5, 7, 11]
