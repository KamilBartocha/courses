# %% [markdown]
# # 07 Python intermediate - wyjątki
# _Kamil Bartocha_ | _wersja 2.0_

# %% [markdown]
# ## Rozkład jazdy
#
# 1. 🔹 **try / except / else / finally** - struktura i przepływ
# 2. 🔹 **Wbudowane wyjątki** - najczęstsze typy, łapanie wielu naraz
# 3. 🔹 **Podnoszenie wyjątków** - `raise`, walidacja danych
# 4. 🔹 **Własne wyjątki** - klasa dziedzicząca po `Exception`
#
# 🐍 Każda sekcja zawiera ćwiczenia.

# %% [markdown]
# ## 1. 🔹 try / except / else / finally
#
# Wyjątek (exception) to obiekt sygnalizujący błąd lub nieoczekiwaną
# sytuację podczas działania programu. Zamiast przerywać program,
# możemy wyjątek *przechwycić* i obsłużyć w kontrolowany sposób.
#
# Pełna struktura bloku:
#
# ```
# try:
#     # kod, który może zgłosić wyjątek
# except SomeError as e:
#     # wykonywany gdy wyjątek wystąpił
# else:
#     # wykonywany tylko gdy NIE było wyjątku
# finally:
#     # wykonywany ZAWSZE (niezależnie od wyniku)
# ```
#
# | Blok | Kiedy się wykonuje |
# |------|-------------------|
# | `except` | wyjątek wystąpił |
# | `else` | wyjątek NIE wystąpił |
# | `finally` | zawsze - do sprzątania zasobów |
#
# > 💡 **Tip:** `else` i `finally` są opcjonalne. W praktyce
# > `finally` używamy głównie do zamykania plików i połączeń,
# > a `else` - gdy chcemy wyraźnie oddzielić kod "sukcesu"
# > od kodu obsługi błędu.

# %%
def divide(a, b):
    try:
        result = a / b
    except ZeroDivisionError as e:
        print(f"Error: {e}")
        return None
    else:
        print("Division successful")
        return result
    finally:
        print("--- done ---")


print(divide(10, 2))   # else + finally
print(divide(10, 0))   # except + finally

# %% [markdown]
# ---

# %% [markdown]
# ### 🐍 Ćwiczenia - try / except / else / finally
#
# **Ćw. 1.** Uzupełnij funkcję `safe_open(path)`, która:
# - próbuje otworzyć plik i zwrócić jego zawartość
# - w `except` wyświetla komunikat i zwraca `None`
# - w `finally` wyświetla `"--- done ---"`
#
# **Ćw. 2.** Napisz blok `try/except/else`, który:
# - konwertuje napis `value` na `int`
# - w `except ValueError` wyświetla `"Not a number"`
# - w `else` wyświetla wynik podniesiony do kwadratu
#
# **Ćw. 3. *(Trudniejsze)*** Napisz funkcję `safe_divide(a, b)`,
# która obsługuje zarówno `ZeroDivisionError`, jak i `TypeError`
# (gdy argumenty nie są liczbami). Zwraca wynik lub `None`.
#
# **Ćw. 4.** Napisz funkcję `compute(text, divisor)`, która używa
# wszystkich czterech bloków naraz:
# - `try`: parsuje `text` na `int` i dzieli przez `divisor`
# - `except`: obsługuje `ValueError` i `ZeroDivisionError`
# - `else`: wyświetla `"Result: {wynik}"`
# - `finally`: wyświetla `"--- done ---"`

# %%
# Ćw. 1: safe_open
def safe_open(path):
    try:
        ...
    except FileNotFoundError as e:
        print(f"Error: {e}")
        return None
    finally:
        ...


result = safe_open("missing.txt")
print(result)   # None

# %%
# Ćw. 2: try/except/else - konwersja
value = "42"

try:
    number = ...
except ValueError:
    ...
else:
    ...

# %%
# Ćw. 3: safe_divide
def safe_divide(a, b):
    # hint: two except clauses
    ...


print(safe_divide(10, 2))    # 5.0
print(safe_divide(10, 0))    # None
print(safe_divide(10, 'x'))  # None

# %%
# Ćw. 4: wszystkie 4 bloki
def compute(text, divisor):
    # hint: try/except/else/finally
    try:
        ...
    except (ValueError, ZeroDivisionError) as e:
        print(f"Error: {e}")
    else:
        ...
    finally:
        ...


compute("10", 4)   # Result: 2.5  --- done ---
compute("abc", 2)  # Error: ...   --- done ---
compute("10", 0)   # Error: ...   --- done ---

# %% [markdown]
# ## 2. 🔹 Wbudowane wyjątki
#
# Python posiada dziesiątki wbudowanych typów wyjątków. Warto znać
# najczęściej spotykane:
#
# | Wyjątek | Kiedy się pojawia |
# |---------|------------------|
# | `ZeroDivisionError` | dzielenie przez zero |
# | `TypeError` | nieodpowiedni typ argumentu |
# | `ValueError` | poprawny typ, ale zła wartość |
# | `NameError` | odwołanie do niezdefiniowanej zmiennej |
# | `IndexError` | indeks poza zakresem listy |
# | `KeyError` | brak klucza w słowniku |
# | `FileNotFoundError` | plik lub katalog nie istnieje |
# | `AttributeError` | obiekt nie ma podanego atrybutu |
#
# Jeden blok `try` może mieć wiele klauzul `except`. Python sprawdza
# je po kolei i wykonuje pierwszą pasującą.
#
# > 💡 **Tip:** `except Exception` łapie prawie wszystko, ale ukrywa
# > błędy programistyczne. Zawsze wymieniaj konkretne typy wyjątków,
# > które faktycznie się spodziewasz.

# %%
# Kilka typow wyjatkow naraz
def process(value, data):
    try:
        number = int(value)
        result = data[number]
        return 00 / result
    except ValueError:
        print("Cannot convert to int")
    except IndexError:
        print("Index out of range")
    except ZeroDivisionError:
        print("Division by zero")
    return None


print(process("2",  [10, 20, 0]))   # ZeroDivisionError
print(process("5",  [10, 20, 5]))   # IndexError
print(process("ab", [10, 20, 5]))   # ValueError

# %%
# Tupla wyjatkow w jednym except
items = {"apple": 3, "banana": 5}

for key in ["apple", "cherry", "banana"]:
    try:
        print(f"{key}: {items[key]}")
    except (KeyError, TypeError) as e:
        print(f"Skipping {key}: {type(e).__name__}")

# %% [markdown]
# ### 🐍 Ćwiczenia - Wbudowane wyjątki
#
# **Ćw. 5.** Uzupełnij pętlę: dla każdego elementu z listy `values`
# spróbuj wypisać `100 / int(v)`. Obsłuż `ValueError` i
# `ZeroDivisionError` osobnymi klauzulami `except`.
#
# **Ćw. 6.** Napisz funkcję `get_item(lst, index)`, która zwraca
# element listy lub `None` gdy indeks jest poza zakresem.
#
# **Ćw. 7. *(Trudniejsze)*** Napisz `safe_get(data, key, default=None)`,
# która działa jak `dict.get()`, ale obsługuje też przypadek gdy
# `data` nie jest słownikiem (`TypeError`).

# %% [markdown]
# # Ćw. 5: wiele klauzul except
# values = ["5", "0", "abc", "10", ""]
#
# for v in values:
#     try:
#         ...
#     except ValueError:
#         print(f"Cannot convert: {v!r}")
#     except ZeroDivisionError:
#         print("Division by zero")
#
# # 20.0
# # Division by zero
# # Cannot convert: 'abc'
# # 10.0
# # Cannot convert: ''

# %%
# Ćw. 6: get_item
def get_item(lst, index):
    ...


print(get_item([10, 20, 30], 1))   # 20
print(get_item([10, 20, 30], 9))   # None

# %%
# Ćw. 7: safe_get
def safe_get(data, key, default=None):
    ...


config = {"host": "localhost", "port": 8080}
print(safe_get(config, "host"))          # localhost
print(safe_get(config, "timeout", 30))   # 30
print(safe_get(None, "host", "n/a"))     # n/a

# %%
# Ćw. 6: safe_get
def safe_get(data, key, default=None):
    ...


config = {"host": "localhost", "port": 8080}
print(safe_get(config, "host"))          # localhost
print(safe_get(config, "timeout", 30))   # 30
print(safe_get(None, "host", "n/a"))     # n/a

# %% [markdown]
# ## 3. 🔹 Podnoszenie wyjątków (`raise`)
#
# Słowo kluczowe `raise` służy do *ręcznego* zgłoszenia wyjątku.
# Używamy go gdy chcemy wymusić warunki poprawności danych wejściowych
# lub sygnalizować błąd logiczny w programie.
#
# ```python
# raise ValueError("message")   # zgłoś z komunikatem
# raise                          # ponownie zgłoś aktywny wyjątek
# ```
#
# Dobre praktyki:
# - wybierz *konkretny* typ wyjątku (nie `Exception` jeśli nie musisz)
# - napisz *jasny komunikat* z wartością, która zawodzi
# - `raise` bez argumentu w bloku `except` przekazuje wyjątek dalej

# %%
# Walidacja argumentow przez raise
def set_age(age):
    if not isinstance(age, int):
        raise TypeError(f"Age must be int, got {type(age).__name__}")
    if age < 0 or age > 150:
        raise ValueError(f"Age {age} is out of range [0, 150]")
    return age


print(set_age(25))    # 25
print(set_age(-1))    # ValueError

# %%
# register_user - raise + try/except razem
users = ['alice', 'bob', 'carol']


def register_user(username, password):
    if username in users:
        raise ValueError(f"Username '{username}' already taken")
    if len(password) < 8:
        raise ValueError("Password must be at least 8 characters")
    users.append(username)
    print(f"User '{username}' registered successfully")


for username, password in [
    ('dave', 'secret99'),
    ('bob',  'pass1234'),
    ('eve',  'short'),
]:
    try:
        register_user(username, password)
    except ValueError as e:
        print(f"Registration failed: {e}")

# %% [markdown]
# ### 🐍 Ćwiczenia - Podnoszenie wyjątków
#
# **Ćw. 8.** Napisz funkcję `validate_score(score)`, która:
# - zgłasza `TypeError`, gdy `score` nie jest `int`
# - zgłasza `ValueError`, gdy `score < 0` lub `score > 100`
# - zwraca `score` gdy poprawny
#
# **Ćw. 9.** Napisz funkcję `to_upper(text)`, która:
# - zgłasza `TypeError`, gdy `text` nie jest napisem
# - w przeciwnym razie zwraca `text.upper()`
#
# **Ćw. 10. *(Trudniejsze)*** Napisz klasę `BankAccount` z metodą
# `withdraw(amount)`, która zgłasza `ValueError` gdy kwota
# jest ujemna lub przekracza saldo.
#
# **Ćw. 11.** Napisz funkcję `safe_parse(text)`, która:
# - próbuje zwrócić `int(text)`
# - w `except ValueError` loguje komunikat, a następnie ponownie
#   zgłasza wyjątek używając samego `raise`
# - wywołaj ją i obsłuż ponownie zgłoszony wyjątek na zewnątrz

# %% [markdown]
# # Ćw. 8: validate_score
# def validate_score(score):
#     if not isinstance(score, int):
#         ...
#     if score < 0 or score > 100:
#         ...
#     return score
#
#
# print(validate_score(85))    # 85
# try:
#     validate_score(-5)
# except ValueError as e:
#     print(e)                  # Score -5 is out of range [0, 100]
# try:
#     validate_score('A')
# except TypeError as e:
#     print(e)                  # Score must be int, got str

# %%
# Ćw. 9: to_upper
def to_upper(text):
    ...


print(to_upper('hello'))   # HELLO
try:
    to_upper(42)
except TypeError as e:
    print(e)               # Expected str, got int

# %%
# Ćw. 10: BankAccount *(Trudniejsze)*
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        if amount < 0:
            raise ValueError("Amount must be positive")
        if amount > self.balance:
            ...
        self.balance -= amount
        return self.balance


account = BankAccount(100)
print(account.withdraw(30))   # 70
try:
    account.withdraw(200)
except ValueError as e:
    print(e)                  # Insufficient funds: ...

# %%
# Ćw. 11: bare raise (ponowne zgłoszenie)
def safe_parse(text):
    try:
        return int(text)
    except ValueError:
        print(f"Logging: could not parse {text!r}")
        ...   # ponownie zgłoś wyjątek


print(safe_parse("42"))   # 42
try:
    safe_parse("abc")     # Logging: could not parse 'abc'
except ValueError as e:
    print(f"Caught: {e}")

# %%
# Ćw. 9: BankAccount
class BankAccount:
    def __init__(self, balance):
        self.balance = balance

    def withdraw(self, amount):
        if amount < 0:
            raise ValueError("Amount must be positive")
        if amount > self.balance:
            ...
        self.balance -= amount
        return self.balance


account = BankAccount(00)
print(account.withdraw(30))    # 70
print(account.withdraw(200))   # ValueError

# %% [markdown]
# ## 4. 🔹 Własne wyjątki (custom exceptions)
#
# Własny wyjątek tworzymy przez dziedziczenie po klasie `Exception`
# (lub jej podklasie). Dzięki temu możemy:
# - nadać wyjątkowi *znaczącą nazwę* opisującą problem domenowy
# - dodać *dodatkowe atrybuty* (np. kod błędu, wartość, która zawodzi)
# - przechwytywać go *selektywnie* niezależnie od wbudowanych wyjątków
#
# ```python
# class MyError(Exception):
#     pass
#
# class MyErrorWithCode(Exception):
#     def __init__(self, message, code):
#         super().__init__(message)
#         self.code = code
# ```
#
# > 💡 **Tip:** Nazwę własnego wyjątku zawsze kończymy na `Error`
# > (np. `InsufficientFundsError`, `ValidationError`).
# > Ułatwia to rozpoznanie, że mamy do czynienia z wyjątkiem.

# %%
# Prosty wlasny wyjatek
class ValidationError(Exception):
    pass


def validate_username(name):
    if len(name) < 3:
        raise ValidationError(f"Username '{name}' is too short (min 3 chars)")
    if not name.isalnum():
        raise ValidationError(f"Username '{name}' contains invalid characters")
    return name


for name in ['al', 'alice!', 'alice123']:
    try:
        print(validate_username(name))
    except ValidationError as e:
        print(f"Validation failed: {e}")

# %%
### 🐍 Ćwiczenia - Własne wyjątki

**Ćw. 12.** Stwórz klasę `NegativeValueError(Exception)` i użyj jej
w funkcji `square_root(n)`, która zgłasza ten wyjątek dla `n < 0`.

**Ćw. 13.** Stwórz klasę `AgeError(ValueError)` z atrybutem `age`.
Użyj jej w funkcji `check_age(age)`, która wymaga `age >= 18`.
W bloku `except` wyświetl zarówno komunikat, jak i wartość `e.age`.

**Ćw. 14. *(Trudniejsze)*** Stwórz hierarchię wyjątków:
- `StorageError(Exception)` - bazowy
- `FileReadError(StorageError)` - błąd odczytu
- `FileWriteError(StorageError)` - błąd zapisu

Napisz funkcję, która zgłasza `FileReadError`. Sprawdź, że można
ją złapać zarówno jako `FileReadError`, jak i jako `StorageError`.

**Ćw. 15.** Stwórz klasę `ApiError(Exception)` z atrybutem
`status_code` i metodą `__str__`, która zwraca napis w formacie
`"[status_code] treść"`.

**Ćw. 16. *(Trudniejsze)*** Stwórz hierarchię: `PaymentError(Exception)`
z atrybutem `amount`, oraz podklasy `InsufficientFundsError` i
`CardDeclinedError`. Napisz funkcję `process_payment(amount, method)`
i złap oba błędy przez klasę bazową, wyświetlając typ i kwotę.

# %% [markdown]
# import math
#
# # Ćw. 12: NegativeValueError
# class NegativeValueError(Exception):
#     pass
#
#
# def square_root(n):
#     if n < 0:
#         ...
#     return math.sqrt(n)
#
#
# print(square_root(9))   # 3.0
# try:
#     square_root(-4)
# except NegativeValueError as e:
#     print(e)            # Cannot compute square root of -4

# %% [markdown]
# # Ćw. 13: AgeError z atrybutem
# class AgeError(ValueError):
#     def __init__(self, message, age):
#         super().__init__(message)
#         ...
#
#
# def check_age(age):
#     if age < 18:
#         ...
#     return "Access granted"
#
#
# try:
#     print(check_age(15))
# except AgeError as e:
#     print(e)        # Must be 18 or older
#     print(e.age)    # 15

# %%
# Ćw. 14: hierarchia wyjatkow *(Trudniejsze)*
class StorageError(Exception):
    pass

class FileReadError(StorageError):
    pass

class FileWriteError(StorageError):
    pass


def read_config(path):
    raise FileReadError(f"Cannot read: {path}")


# Zlapanie konkretnego wyjatku:
try:
    read_config("config.json")
except FileReadError as e:
    print(f"FileReadError: {e}")

# Zlapanie przez klase bazowa:
try:
    read_config("config.json")
except StorageError as e:
    print(f"StorageError: {e}")

# %%
# Ćw. 15: ApiError z __str__
class ApiError(Exception):
    def __init__(self, message, status_code):
        super().__init__(message)
        self.status_code = status_code

    def __str__(self):
        ...   # zwróć "[status_code] message"


try:
    raise ApiError("Not Found", status_code=404)
except ApiError as e:
    print(e)              # [404] Not Found
    print(e.status_code)  # 404

# %%
# Ćw. 16: hierarchia z atrybutem *(Trudniejsze)*
class PaymentError(Exception):
    def __init__(self, message, amount):
        super().__init__(message)
        self.amount = amount


class InsufficientFundsError(PaymentError):
    pass


class CardDeclinedError(PaymentError):
    pass


def process_payment(amount, method):
    if method == "empty":
        raise InsufficientFundsError("Not enough funds", amount)
    if method == "blocked":
        raise CardDeclinedError("Card blocked", amount)


for method in ["empty", "blocked"]:
    try:
        process_payment(100, method)
    except PaymentError as e:
        print(f"{type(e).__name__}: {e} (amount={e.amount})")

# InsufficientFundsError: Not enough funds (amount=100)
# CardDeclinedError: Card blocked (amount=100)

# %%
# Ćw. 11: AgeError z atrybutem
class AgeError(ValueError):
    def __init__(self, message, age):
        super().__init__(message)
        ...


def check_age(age):
    if age < 18:
        ...
    return "Access granted"


try:
    print(check_age(15))
except AgeError as e:
    print(e)        # Must be 18 or older
    print(e.age)    # 15

# %%
# Ćw. 12: hierarchia wyjatkow
class StorageError(Exception):
    pass

class FileReadError(StorageError):
    pass

class FileWriteError(StorageError):
    pass


def read_config(path):
    raise FileReadError(f"Cannot read: {path}")


# Zlapanie konkretnego wyjatku:
try:
    read_config("config.json")
except FileReadError as e:
    print(f"FileReadError: {e}")

# Zlapanie przez klase bazowa:
try:
    read_config("config.json")
except StorageError as e:
    print(f"StorageError: {e}")
