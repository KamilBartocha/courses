# %% [markdown]
# # 002 Python od podstaw - składnia i typy proste
#
# _Kamil Bartocha_ | wersja 2.0

# %% [markdown]
# ## Rozkład jazdy
#
# 1. 🖨️ **`print()` i formatowanie** - wyświetlanie, f-stringi, legacy style
#    - 🐍 Ćwiczenia
# 2. 💬 **Komentarze** - jednolinijkowe i wielolinijkowe
# 3. 📦 **Zmienne i typy danych** - int, float, complex, `type()`, operatory przypisania
#    - 🐍 Ćwiczenia
# 4. ➕ **Arytmetyka i operatory** - matematyczne, porównania, logiczne, zamiana zmiennych
#    - 🐍 Ćwiczenia
# 5. ✅ **Typ logiczny, None i konwersja** - bool, falsy/truthy, NoneType, isinstance()
# 6. 📝 **Łańcuchy znaków** - tworzenie, indeksowanie, wycinanie, metody
#    - 🐍 Ćwiczenia
# 7. ⌨️ **Dane wejściowe** - funkcja `input()`, konwersja typów
#    - 🐍 Ćwiczenia

# %% [markdown]
# ---
# ## 1. 🖨️ `print()` i formatowanie

# %% [markdown]
# Funkcja `print()` wyświetla wartości na ekranie. Możemy przekazać
# jej dosłowny tekst (w cudzysłowach), zmienną lub wyrażenie.
#
# Trzy popularne sposoby łączenia tekstu ze zmiennymi:
#
# | Sposób | Przykład |
# |---|---|
# | konkatenacja | `"Wiek: " + str(age)` |
# | `.format()` | `"Wiek: {}".format(age)` |
# | f-string | `f"Wiek: {age}"` |
#
# > 💡 Zalecamy używanie **f-stringów** - są najbardziej czytelne
# > i wydajne. Dostępne od Pythona 3.6.

# %%
name = "Alice"
age = 25

# trzy sposoby wypisania tego samego
print("Imię: " + name)               # konkatenacja
print("Imię: {}".format(name))       # .format()
print(f"Imię: {name}, wiek: {age}")  # f-string (zalecany)

# print() przyjmuje wiele argumentów - oddziela spacją
print("Wartości:", 1, 2, 3)
print("Suma 2+2 =", 2 + 2)

# %% [markdown]
# ### Starsze sposoby formatowania
#
# Python ma trzy sposoby wstawiania wartości do napisów. Zalecamy
# f-stringi, ale warto znać starsze metody - są powszechne w cudzym kodzie:
#
# | Sposób | Przykład | Uwagi |
# |---|---|---|
# | `%` operator | `"%s ma %d lat" % (name, age)` | Python 2 / legacy |
# | `.format()` | `"{} ma {} lat".format(name, age)` | Python 2.6+, nadal popularny |
# | f-string | `f"{name} ma {age} lat"` | Python 3.6+, **zalecany** |
#
# > 💡 Ucząc się Pythona skupiamy się na f-stringach. `%` i `.format()`
# > poznajemy by rozumieć istniejący kod - nowego kodu w tych stylach
# > nie piszemy.

# %%
name = "Alice"
age = 25

# % operator - najstarszy sposób (spotykamy w starym kodzie)
print("Imię: %s, wiek: %d" % (name, age))

# .format() - Python 2.6+, nadal popularny
print("Imię: {}, wiek: {}".format(name, age))
print("Imię: {n}, wiek: {a}".format(n=name, a=age))

# f-string - Python 3.6+, zalecany
print(f"Imię: {name}, wiek: {age}")

# %% [markdown]
# ---
# ### 🐍 Ćwiczenia - `print()`

# %% [markdown]
# 1. Wypisz swoje imię i wiek w jednej linii używając f-stringa.
# 2. Wypisz wynik `7 * 6` jako: `"7 * 6 = 42"` używając f-stringa.
# 3. *(Trudniejsze)* Wypisz `price = 9.99` jako `"Cena: 9.99 PLN"`
#    z formatowaniem do 2 miejsc po przecinku: `f"{price:.2f}"`.

# %%
name = "Alice"
age = 20

print(...)

# %%
a = 7
b = 6

print(f"...")

# %%
price = 9.99

print(f"Cena: ... PLN")

# %% [markdown]
# ---
# ## 2. 💬 Komentarze

# %% [markdown]
# Komentarze (comments) to fragmenty kodu ignorowane przez Pythona.
# Służą do dokumentowania i wyjaśniania logiki programu.
#
# Dwa rodzaje:
# - **Jednolinijkowy**: `# tekst` - od znaku `#` do końca linii
# - **Wielolinijkowy**: tekst między `"""..."""` lub `'''...'''`
#
# > 💡 Dobry komentarz wyjaśnia **dlaczego** kod coś robi, nie
# > **co** robi - to widać z samego kodu. Unikamy komentarzy
# > typu `x = 5  # przypisz 5 do x` - to jest oczywiste.

# %%
# obliczamy pole koła - wzór: pi * r^2
radius = 5
pi = 3.14159
area = pi * radius ** 2
print(f"Pole koła: {area:.2f}")

"""
Program oblicza pole koła na podstawie promienia.
Dane: radius - promień koła (float)
Wynik: area - pole koła (float)
"""

# zakomentowana linia nie jest wykonywana:
# print("Ta linia nie wyświetli się")
print("Koniec programu")

# %% [markdown]
# ---
# ## 3. 📦 Zmienne i typy danych

# %% [markdown]
# Zmienną (variable) tworzymy przez przypisanie wartości operatorem
# `=`. Python automatycznie rozpoznaje typ - nie deklarujemy go.
#
# Typy liczbowe:
#
# | Typ | Przykład | Opis |
# |---|---|---|
# | `int` | `5`, `-3` | liczba całkowita |
# | `float` | `3.14` | liczba zmiennoprzecinkowa |
# | `complex` | `1 + 2j` | liczba zespolona |
#
# Operatory przypisania skróconego (augmented assignment):
#
# | Skrót | Pełny zapis |
# |---|---|
# | `x += 5` | `x = x + 5` |
# | `x -= 5` | `x = x - 5` |
# | `x *= 2` | `x = x * 2` |
#
# > ⚠️ Użycie zmiennej przed przypisaniem powoduje `NameError`.
# > Python nie ma niezainicjalizowanych zmiennych jak w C/Java.

# %%
# przypisanie - Python sam rozpoznaje typ
counter = 0
price = 19.99
pi = 3.14159

print(type(counter))    # <class 'int'>
print(type(price))      # <class 'float'>

# przypisanie skrócone
counter += 1
print(counter)          # 1

price *= 1.23           # +23% VAT
print(f"{price:.2f}")   # 24.59

# %% [markdown]
# Python ma dziewięć wbudowanych typów danych. Każda wartość ma swój typ,
# który możemy sprawdzić funkcją `type()`.
#
# | Typ | Kategoria | Przykład | Mutowalny? |
# |---|---|---|---|
# | `int` | Numeryczny | `42`, `-7` | - |
# | `float` | Numeryczny | `3.14`, `1.5e-3` | - |
# | `complex` | Numeryczny | `1 + 2j` | - |
# | `bool` | Logiczny | `True`, `False` | - |
# | `str` | Tekstowy | `'hello'` | Nie |
# | `list` | Kolekcja | `[1, 2, 3]` | Tak |
# | `tuple` | Kolekcja | `(1, 2, 3)` | Nie |
# | `set` | Kolekcja | `{1, 2, 3}` | Tak |
# | `dict` | Kolekcja | `{'a': 1}` | Tak |
#
# > 💡 **Mutowalny (mutable)** - wartość można zmienić po utworzeniu.
# > Listy, zbiory i słowniki są mutowalne. Napisy, krotki i liczby - nie.

# %%
# type() zwraca typ danej wartości
print(type(42))        # <class 'int'>
print(type(3.14))      # <class 'float'>
print(type(True))      # <class 'bool'>
print(type('hello'))   # <class 'str'>
print(type([1, 2]))    # <class 'list'>
print(type({'a': 1}))  # <class 'dict'>

# %% [markdown]
# ---
# ### 🐍 Ćwiczenia - zmienne

# %% [markdown]
# 1. Utwórz zmienne `first_name`, `last_name`, `age` i wypisz je
#    w jednej linii: `"Alice Smith, lat: 30"`.
# 2. Zmienna `score` zaczyna od `0`. Dodaj do niej `10` trzy razy
#    używając `+=`. Wypisz wynik (oczekiwane: `30`).
# 3. *(Trudniejsze)* Zamień wartości `a = 5`, `b = 3` bez użycia
#    zmiennej pomocniczej. W Pythonie można: `a, b = b, a`.

# %%
first_name = "Alice"
last_name = "Smith"
age = 30

print(...)

# %%
score = 0

...

print(f"Wynik: {score}")  # oczekiwane: 30

# %%
a = 5
b = 3

...

print(f"a={a}, b={b}")  # oczekiwane: a=3, b=5

# %% [markdown]
# ---
# ## 4. ➕ Arytmetyka i operatory

# %% [markdown]
# Python obsługuje wszystkie standardowe operatory arytmetyczne.
#
# | Operator | Opis | Przykład | Wynik |
# |---|---|---|---|
# | `+` | dodawanie | `3 + 2` | `5` |
# | `-` | odejmowanie | `3 - 2` | `1` |
# | `*` | mnożenie | `3 * 2` | `6` |
# | `/` | dzielenie | `5 / 2` | `2.5` |
# | `//` | dzielenie całkowite | `5 // 2` | `2` |
# | `%` | reszta z dzielenia | `5 % 2` | `1` |
# | `**` | potęgowanie | `2 ** 3` | `8` |
#
# > 💡 `/` zawsze zwraca `float`, nawet gdy wynik jest całkowity:
# > `4 / 2` → `2.0`. Użyj `//` gdy potrzebujesz liczby całkowitej.

# %%
print(3 + 2)    # 5
print(5 / 2)    # 2.5  - zawsze float
print(5 // 2)   # 2    - dzielenie całkowite
print(5 % 2)    # 1    - reszta z dzielenia
print(2 ** 8)   # 256  - potęgowanie

# kolejność działań (BODMAS)
print(3 + 5 * 0.5)    # 5.5  - mnożenie pierwsze
print((3 + 5) * 0.5)  # 4.0  - nawiasy pierwsze

# %% [markdown]
# ### Operatory porównania (comparison operators)
#
# Operatory porównania zwracają `True` lub `False`. Używamy ich głównie
# w warunkach `if` i pętlach `while`:
#
# | Operator | Opis | Przykład |
# |---|---|---|
# | `==` | Równe (equal) | `3 == 3` → `True` |
# | `!=` | Różne (not equal) | `3 != 4` → `True` |
# | `>` | Większe (greater than) | `5 > 3` → `True` |
# | `<` | Mniejsze (less than) | `2 < 4` → `True` |
# | `>=` | Większe lub równe | `5 >= 5` → `True` |
# | `<=` | Mniejsze lub równe | `3 <= 4` → `True` |

# %%
x = 5

print(x == 5)   # True
print(x != 5)   # False
print(x > 3)    # True
print(x < 3)    # False
print(x >= 5)   # True
print(x <= 4)   # False

# %% [markdown]
# ### Operatory logiczne (logical operators)
#
# Operatory logiczne łączą wyrażenia boolowskie:
#
# | Operator | Opis |
# |---|---|
# | `not x` | Negacja - odwraca wartość logiczną |
# | `x and y` | Prawdziwe gdy **oba** wyrażenia są prawdziwe |
# | `x or y` | Prawdziwe gdy **przynajmniej jedno** jest prawdziwe |
#
# > 💡 `and`/`or` nie zawsze zwracają `True`/`False` - zwracają jedną z
# > wartości: `0 or 'default'` zwróci `'default'` (bo `0` jest falsy).

# %%
# not - negacja
print(not True)     # False
print(not False)    # True

# and - prawdziwe gdy oba
age = 20
is_healthy = True
print(age >= 18 and is_healthy)   # True

# or - prawdziwe gdy przynajmniej jedno
is_phone = True
is_pc = False
print(is_phone or is_pc)          # True

# or zwraca pierwszą 'truthy' wartość
result = 0 or 'default'
print(result)   # default

# %% [markdown]
# ### Zamiana wartości zmiennych (variable swap)
#
# Python pozwala zamieniać wartości zmiennych w jednej linii - bez zmiennej
# pomocniczej, dzięki rozpakowaniu krotki (tuple unpacking):
#
# | Podejście | Kod |
# |---|---|
# | Inne języki - zmienna pomocnicza | `temp = a; a = b; b = temp` |
# | Python - tuple unpacking | `a, b = b, a` |

# %%
a = 5
b = 7

# Python: elegancki swap bez zmiennej pomocniczej
a, b = b, a
print(f'a={a}, b={b}')   # a=7, b=5

# Inne języki: wymaga zmiennej pomocniczej (temp)
a = 5
b = 7
temp = a
a = b
b = temp
print(f'a={a}, b={b}')   # a=7, b=5

# %% [markdown]
# ---
# ### 🐍 Ćwiczenia - arytmetyka

# %% [markdown]
# 1. Oblicz pole prostokąta o bokach `width = 7` i `height = 4`.
# 2. Sprawdź, jaka jest reszta z dzielenia `17` przez `5`.
# 3. *(Trudniejsze)* Oblicz zysk z lokaty:
#    `amount = 10000`, `rate = 0.08` (8%), `years = 3`.
#    Wzór: `amount * (1 + rate) ** years - amount`.
#    Wynik zaokrąglij do 2 miejsc: `round(result, 2)`.

# %%
width = 7
height = 4

area = ...
print(f"Pole: {area}")

# %%
number = 17
divisor = 5

remainder = ...
print(f"Reszta: {remainder}")

# %%
amount = 10000
rate = 0.08
years = 3

profit = ...
print(f"Zysk: {round(profit, 2)} PLN")

# %% [markdown]
# ---
# ### 🐍 Ćwiczenia - operatory logiczne

# %%
# Ćwiczenie 1 - operatory arytmetyczne
a = 17
b = 5
print(a / b)     # dzielenie
print(...)       # dzielenie całkowite
print(...)       # reszta z dzielenia

# %%
# Ćwiczenie 2 - operatory logiczne
temperature = 22
print(temperature >= 18 and ...)   # między 18 a 30
print(not ...)                     # nie większa niż 25

# %%
# Ćwiczenie 3 - zamiana zmiennych
x = 'hello'
y = 'world'
...   # zamień x i y
print(x)
print(y)

# %% [markdown]
# ---
# ## 5. ✅ Typ logiczny, None i konwersja typów

# %% [markdown]
# ### Typ logiczny (boolean)
#
# `bool` to typ z dokładnie dwiema wartościami: `True` lub `False`. Wyniki
# operatorów porównania to zawsze `bool`.
#
# > 💡 Wiele wartości ma naturalne odpowiedniki logiczne. "Falsy" wartości
# > (`0`, `0.0`, `''`, `[]`, `{}`, `None`) traktowane są jak `False`,
# > a wszystkie pozostałe jak `True`.

# %%
print(True, type(True))   # True <class 'bool'>

# Wyniki porównań to bool
print(2 > 8)     # False
print(10 >= 10)  # True

# Falsy vs truthy
print(bool(0))    # False
print(bool(''))   # False
print(bool([]))   # False
print(bool(42))   # True
print(bool('hi')) # True

# %% [markdown]
# ### Typ `None` i `NoneType`
#
# `None` to specjalna wartość Pythona oznaczająca "brak wartości". Jej
# typ to `NoneType`. Pojawia się w trzech typowych sytuacjach:
#
# | Sytuacja | Przykład |
# |---|---|
# | Funkcja bez `return` | `result = print("hello")` → `None` |
# | Brakujący klucz w słowniku | `d.get('klucz')` → `None` |
# | Jawne "brak wartości" | `x = None` |
#
# Zawsze porównujemy `None` przez `is`, nie `==`:
# ```python
# if x is None:    # ✅ poprawnie
# if x == None:    # ⚠️ działa, ale nie jest Pythonic
# ```
#
# > 💡 `None` jest "falsy" - `if None:` wykonuje blok `else`.
# > Uważajmy jednak: `if x is None:` i `if not x:` to nie to samo -
# > `not x` jest też `True` dla `0`, `""`, `[]`.

# %%
# None to jedyna wartość typu NoneType
x = None
print(x)           # None
print(type(x))     # <class 'NoneType'>

# Funkcja bez return zwraca None
def greet(name):
    print(f"Hello, {name}!")    # wypisuje, ale nic nie zwraca

result = greet("Alice")
print(result)      # None - bo greet() nie ma return

# Sprawdzamy czy wartość to None
if result is None:
    print("Funkcja nic nie zwróciła")

# None jako wartość domyślna w słowniku
scores = {'Alice': 95}
print(scores.get('Bob'))        # None - klucz nie istnieje
print(scores.get('Bob', 0))     # 0 - wartość domyślna

# %% [markdown]
# ### `isinstance()` - sprawdzanie typu
#
# `isinstance(obj, Klasa)` zwraca `True` jeśli `obj` jest instancją
# `Klasa` lub jej podklasy. Preferowane nad `type(obj) == Klasa`:
#
# | Sprawdzenie | `type(x) == int` | `isinstance(x, int)` |
# |---|---|---|
# | `x = 42` | `True` | `True` |
# | `x = True` | `False` | `True` (bool dziedziczy po int) |
# | Wiele typów | Niemożliwe prosto | `isinstance(x, (int, float))` |
#
# ```python
# isinstance(obj, Klasa)           # pojedyncza klasa
# isinstance(obj, (Klasa1, Klasa2)) # jedno z wielu
# ```
#
# > 💡 `isinstance()` stosujemy gdy potrzebujemy sprawdzić typ przed
# > operacją - np. w walidacji argumentów funkcji.

# %%
print(isinstance(42, int))        # True
print(isinstance(3.14, float))    # True
print(isinstance("hi", str))      # True
print(isinstance([1, 2], list))   # True

# isinstance sprawdza też podklasy
print(isinstance(True, bool))     # True
print(isinstance(True, int))      # True - bool jest podklasą int!

# Sprawdzanie wielu typów naraz
def show_type(x):
    if isinstance(x, (int, float)):
        print(f"{x} to liczba")
    elif isinstance(x, str):
        print(f"{x!r} to napis")
    else:
        print(f"{x} to inny typ: {type(x).__name__}")

show_type(42)
show_type(3.14)
show_type("hello")
show_type([1, 2, 3])

# %% [markdown]
# ### Konwersja typów (type conversion)
#
# Konwertujemy między typami wbudowanymi funkcjami:
#
# | Funkcja | Konwertuje na | Przykład |
# |---|---|---|
# | `int(x)` | Liczba całkowita | `int(3.9)` → `3` |
# | `float(x)` | Liczba zmiennoprzecinkowa | `float(7)` → `7.0` |
# | `str(x)` | Napis | `str(42)` → `'42'` |
# | `bool(x)` | Wartość logiczna | `bool(0)` → `False` |
#
# > ⚠️ `int()` **obcina** część ułamkową, nie zaokrągla: `int(3.9)` → `3`.
# > Użyj `round()`, żeby zaokrąglić do najbliższej liczby całkowitej.

# %%
# int → float
x = 7
print(float(x))   # 7.0

# float → int (obcina, nie zaokrągla!)
y = 3.99
print(int(y))     # 3  ← obcina
print(round(y))   # 4  ← zaokrągla

# str → int
s = '42'
print(int(s), type(int(s)))   # 42 <class 'int'>

# int → str (wymagane do konkatenacji z napisem)
age = 25
print('Age: ' + str(age))   # Age: 25

# %% [markdown]
# ---
# ## 6. 📝 Łańcuchy znaków (strings)

# %% [markdown]
# Łańcuch znaków (string) to ciąg znaków w cudzysłowach `""` lub
# apostrofach `''`. Python nie rozróżnia między nimi.
#
# Znaki specjalne (escape sequences):
#
# | Sekwencja | Znaczenie |
# |---|---|
# | `\n` | nowa linia |
# | `\t` | tabulacja |
# | `\\` | dosłowny backslash |
# | `\'` | dosłowny apostrof |
#
# Dodaj `r` przed stringiem aby wyłączyć interpretację sekwencji:
# `r"C:\Users\name"` wypisze dosłownie `C:\Users\name`.
#
# > ⚠️ Stringi są **niezmienne (immutable)** - nie modyfikujemy
# > pojedynczego znaku. Tworzymy nowy string: `"J" + word[1:]`.

# %%
greeting = "Hello, World!"
name = 'Alice'

# konkatenacja i mnożenie stringa
print("Hello, " + name + "!")
print("-" * 30)

# znaki specjalne
print("Linia 1\nLinia 2")   # \n = nowa linia
print("Kol 1\tKol 2")       # \t = tabulacja

# raw string - backslash nie jest interpretowany
path = r"C:\Users\name"
print(path)

# %% [markdown]
# Stringi możemy **indeksować (indexing)** - pierwszy znak ma indeks
# `0`, ostatni `-1`.
#
# ```
#  +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#    0   1   2   3   4   5
#   -6  -5  -4  -3  -2  -1
# ```
#
# **Wycinanie (slicing)**: `s[start:stop]` - stop jest wyłączony.
#
# | Wyrażenie | Wynik | Opis |
# |---|---|---|
# | `s[0]` | `'P'` | pierwszy znak |
# | `s[-1]` | `'n'` | ostatni znak |
# | `s[0:2]` | `'Py'` | indeksy 0, 1 |
# | `s[2:]` | `'thon'` | od 2 do końca |
# | `s[:3]` | `'Pyt'` | od początku do 3 |
# | `s[::-1]` | `'nohtyP'` | odwrócony string |

# %%
word = "Python"

print(word[0])       # P   - pierwszy znak
print(word[-1])      # n   - ostatni znak
print(word[0:2])     # Py
print(word[2:])      # thon
print(word[:3])      # Pyt
print(word[::-1])    # nohtyP - krok -1 = od końca

print(len(word))     # 6 - długość (length)

# niezmienność - budujemy nowy string
new_word = "J" + word[1:]
print(new_word)      # Jython

# %% [markdown]
# ### Metody łańcuchów znaków (string methods)
#
# | Metoda | Co robi | Przykład |
# |---|---|---|
# | `len(s)` | Długość napisu | `len('hello')` → `5` |
# | `s.upper()` | Wielkie litery | `'abc'.upper()` → `'ABC'` |
# | `s.lower()` | Małe litery | `'ABC'.lower()` → `'abc'` |
# | `s.strip()` | Usuwa białe znaki z brzegów | `'  hi  '.strip()` → `'hi'` |
# | `s.replace(a, b)` | Zastępuje `a` przez `b` | `'aXb'.replace('X', '-')` → `'a-b'` |
# | `s.split(sep)` | Dzieli na listę | `'a,b'.split(',')` → `['a', 'b']` |
# | `s.count(sub)` | Zlicza wystąpienia | `'hello'.count('l')` → `2` |
# | `s.startswith(p)` | Sprawdza prefix | `'Python'.startswith('Py')` → `True` |

# %%
text = 'Hello, World!'

print(len(text))                 # 13
print(text.upper())              # HELLO, WORLD!
print(text.lower())              # hello, world!
print(text.replace('o', '0'))    # Hell0, W0rld!
print(text.count('l'))           # 3
print(text.split(', '))          # ['Hello', 'World!']
print(text.startswith('Hello'))  # True

s = '   python   '
print(s.strip())   # python

# %% [markdown]
# ---
# ### 🐍 Ćwiczenia - łańcuchy znaków

# %% [markdown]
# 1. Ze stringa `sentence = "Hello, Python!"` wytnij i wypisz
#    słowo `"Hello"` (znaki od indeksu 0 do 5).
# 2. Dla `word = "programming"` wypisz: długość słowa oraz
#    ostatni znak używając indeksowania ujemnego.
# 3. *(Trudniejsze)* Ze stringa `email = "alice@example.com"`
#    wytnij samą nazwę użytkownika (część przed `@`).
#    Hint: `at_pos = email.index("@")` zwróci pozycję `@`.

# %%
sentence = "Hello, Python!"

hello = ...
print(hello)

# %%
word = "programming"

length = ...
last_char = ...

print(f"Długość: {length}, ostatni: '{last_char}'")

# %%
email = "alice@example.com"

at_pos = email.index("@")
username = ...
print(f"Nazwa użytkownika: {username}")

# %% [markdown]
# **Ćwiczenie 4.** Dany napis o nieparzystej długości > 7. Wydrukuj
# trzy środkowe znaki.
#
# **Ćwiczenie 5.** Dane `s1 = 'FullStack'` i `s2 = 'Python'`. Wstaw
# `s2` w środek `s1`. Oczekiwany wynik: `'FullPythonStack'`.
#
# **Ćwiczenie 6.** Odwróć napis `str1 = 'Python'` używając wycinania.
# Oczekiwany wynik: `'nohtyP'`.
#
# **Ćwiczenie 7.** Dla `text = 'Python is great!'` wydrukuj wersję
# z wielkimi i małymi literami.

# %%
# Ćwiczenie 2 - wstaw s2 w środek s1
s1 = 'FullStack'
s2 = 'Python'
mid = len(s1) // 2
result = s1[:mid] + ... + s1[mid:]
print(result)   # FullPythonStack

# %%
# Ćwiczenie 3 - odwróć napis (slicing)
str1 = 'Python'
reversed_str = str1[...]
print(reversed_str)   # nohtyP

# %%
# Ćwiczenie 4 - wielkie i małe litery
text = 'Python is great!'
print(...)   # PYTHON IS GREAT!
print(...)   # python is great!

# %% [markdown]
# ---
# ## 7. ⌨️ Dane wejściowe - `input()`

# %% [markdown]
# Funkcja `input()` zatrzymuje program i czeka, aż użytkownik wpisze
# tekst i naciśnie Enter. Zwraca zawsze **string** - nawet gdy
# użytkownik wpisze liczbę.
#
# Aby użyć wartości jako liczby, musimy jawnie skonwertować typ:
#
# | Konwersja | Przykład | Wynik |
# |---|---|---|
# | `int(input())` | `"42"` → `42` | liczba całkowita |
# | `float(input())` | `"3.14"` → `3.14` | liczba zmiennoprzecinkowa |
# | `str(input())` | `"Alice"` → `"Alice"` | string (domyślny) |
#
# > ⚠️ Jeśli użytkownik wpisze tekst tam, gdzie oczekujemy liczby,
# > `int()` lub `float()` zgłosi `ValueError`. Obsługę błędów
# > poznamy w module o wyjątkach.

# %%
# input() zawsze zwraca string
name = input("Podaj imię: ")
print(f"Cześć, {name}!")

# konwersja na int aby wykonać obliczenia
age = int(input("Podaj wiek: "))
print(f"Za 10 lat będziesz mieć {age + 10} lat.")

# %% [markdown]
# ---
# ### 🐍 Ćwiczenia - dane wejściowe

# %% [markdown]
# 1. Napisz program, który pyta użytkownika o imię i wypisuje
#    powitanie: `"Witaj, <imię>!"`.
# 2. Poproś użytkownika o dwie liczby całkowite i wypisz ich
#    sumę, różnicę i iloczyn.
# 3. *(Trudniejsze)* Poproś o imię i rok urodzenia. Oblicz
#    przybliżony wiek (2024 - rok urodzenia) i wypisz:
#    `"<imię> ma około <wiek> lat."`

# %%
name = input("Podaj imię: ")

print(...)

# %%
a = int(input("Podaj pierwszą liczbę: "))
b = int(input("Podaj drugą liczbę: "))

print(f"Suma: {...}")
print(f"Różnica: {...}")
print(f"Iloczyn: {...}")

# %%
name = input("Podaj imię: ")
birth_year = int(input("Podaj rok urodzenia: "))

age = ...
print(f"...")
